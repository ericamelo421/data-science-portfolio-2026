# %%
print("bienvenu dans le monde des donnees" )
### les commentaire
# Out:
# bienvenu dans le monde des donnees

# %% [markdown]
# # creation de variable

# %%
x=5
print(x)
# Out:
# 5

# %%
x= "python"
print(x)
# Out:
# python

# %% [markdown]
# # afficher les varaiable en phyton

# %%
Nom = "bob" # nom de l'utiliateur
age = 16   # age de l'utilisateur

# %%
print(f"Nom:{Nom}")
print(f"age:{age}")
print(f"bonjour et bienvenu sur logmercent je m'appelle {Nom} et j'ai {age} ans" )
# Out:
# Nom:bob
# age:16
# bonjour et bienvenu sur logmercent je m'appelle bob et j'ai 16 ans

# %% [markdown]
# # thype de donnees en python

# %% [markdown]
# phyton propose plusieur type de variable
#  -les int : le entier (1)\
#  -les float :les decimaux(2.8)
#  -les str: les  chaines de caracteres ("bonjour")
#  -les bool:les booleans (true ,false)

# %%
age = 20 
taille= 1,65
prenom= "suny"
d=True

# %%
type(age)
# Out:
# int

# %%
Nom
# Out:
# 'bob'

# %%
print("bonjour,"+Nom)
# Out:
# bonjour,bob
