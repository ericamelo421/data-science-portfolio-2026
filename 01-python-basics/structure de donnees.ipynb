# %%
fruits =['pomme','cerise','mangue','banane']
print (fruits)
# Out:
# ['pomme', 'cerise', 'mangue', 'banane']

# %% [markdown]
# # liste

# %%
fruits[3]
# Out:
# 'banane'

# %%
fruits[-1]
# Out:
# 'banane'

# %%
fruits[0]
# Out:
# 'pomme'

# %%
len(fruits)
# Out:
# 4

# %%
for fruit in fruits:
  print(fruit)
# Out:
# pomme
# cerise
# mangue
# banane

# %%
# mise ajour des element d'une liste
fruits [0]="orange"

# %%
fruits
# Out:
# ['orange', 'cerise', 'mangue', 'banane']

# %%
fruits.append("kiwi")
fruits
# Out:
# ['orange', 'cerise', 'mangue', 'banane', 'kiwi']

# %%
fruits.insert(0,'goayave')
fruits
# Out:
# ['goayave', 'orange', 'cerise', 'mangue', 'banane', 'kiwi']

# %%
fruits.remove('orange')
fruits
# Out:
# ['goayave', 'mangue', 'banane', 'kiwi']

# %%
del fruits [0]
fruits
# Out:
# ['banane', 'kiwi']

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %% [markdown]
# # comprehension de liste

# %%
nombres =[1,2,3,4,5]

# %%
carees= [x**2 for x in nombres]
carees
# Out:
# [1, 4, 9, 16, 25]

# %%
b
