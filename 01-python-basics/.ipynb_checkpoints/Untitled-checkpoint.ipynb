# %%
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
x
# Out:
# [['a', 'b', 'c'], [1, 2, 3]]

# %%
letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
letters

# replace some values


# now remove them
letters[2:5] = []
letters

# clear the list by replacing all the elements with an empty list
letters[:] = []
letters
# Out:
# []

# %%
letters[2:5] = ['C', 'D', 'E']
letters
