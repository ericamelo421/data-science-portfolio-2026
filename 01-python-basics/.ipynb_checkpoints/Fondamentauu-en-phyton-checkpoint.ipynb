# %%
print("bienvenu dans le monde des donnees" )
### les commentaire
# Out:
# bienvenu dans le monde des donnees

# %% [markdown]
# # creation de variable

# %%
x=5
print(x)
# Out:
# 5

# %%
x= "python"
print(x)
# Out:
# python

# %% [markdown]
# # afficher les varaiable en phyton

# %%
Nom = "bob" # nom de l'utiliateur
age = 16  # age de l'utilisateur

# %%
print(f"Nom:{Nom}")
print(f"age:{age}")
print(f"bonjour et bienvenu sur logmercent je m'appelle {Nom}et j'ai {age}")
# Out:
# Nom:bob
# age:16
