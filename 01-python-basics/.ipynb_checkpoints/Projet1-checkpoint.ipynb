# %%
def lire_csv(nom_fichier, nom_colonne):
    valeurs = []

    with open(nom_fichier, "r", encoding="utf-8") as fichier:
        lecteur = csv.DictReader(fichier)
        for ligne in lecteur:
            try:
                valeurs.append(float(ligne[nom_colonne]))
            except ValueError:
                print(f"Valeur ignorée (non numérique) : {ligne[nom_colonne]}")

    return valeurs

# %%
valeurs = lire_csv("depenses.csv", "montant")
print(valeurs)
print(len(valeurs))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 valeurs = lire_csv("depenses.csv", "montant")
#       2 print(valeurs)
#       3 print(len(valeurs))
#
# NameError: name 'lire_csv' is not defined
