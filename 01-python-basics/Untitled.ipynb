# %%
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
x
# Out:
# [['a', 'b', 'c'], [1, 2, 3]]

# %%
letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
letters

# replace some values




# clear the list by replacing all the elements with an empty list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
letters[2:5] = ['C', 'D', 'E']
letters
# Out:
# ['C', 'D', 'E']

# %%
# now remove them
letters[2:5] = []
letters
# Out:
# []

# %%
letters[:] = []
letters
# Out:
# []

# %%
prenom = "l'apprentisage"
print(prenom)
# Out:
# l'apprentisage

# %% [markdown]
# ### ceci est un texte de niveau 3

# %% [markdown]
# ceci est un mot en **gras**

# %% [markdown]
# ceci est en gras et en ***italic***
